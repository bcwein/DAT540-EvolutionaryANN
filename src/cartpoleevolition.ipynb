# %% [markdown]
# # Demonstration of the cartpoleevolution class
#
# ## Import cartpoleevolution

# %%
from cartpoleevolution import cartpoleevolution

sim = cartpoleevolution()

# %% [markdown]
# ## Import other libraries

# %%
import pandas as pd 
import seaborn as sns

# Global settings
sns.set_style("darkgrid")

# %% [markdown]
# ## Run the code and collect metrics

# %%
f = sim.simulate(generations=10, agents=50, max_episode_steps=5000)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-989027c05942> in <module>
# ----> 1 df = sim.simulate(generations=10, agents=50, max_episode_steps=5000)
#
# c:\Users\Bjørn Christian\OneDrive - Universitetet i Stavanger\Skule\UiS\Introduksjon_til_datavitenskap\Eksamen\Gits\DAT540-EvolutionaryANN\src\cartpoleevolution.py in simulate(self, generations, agents, acceptance_rate, max_episode_steps, mutation)
#     225                     terminate = done
#     226
# --> 227                 fit[n] = score
#     228                 scoreList[(agents*i+n) % 100] = score
#     229
#
# IndexError: index 50 is out of bounds for axis 0 with size 50

# %% [markdown]
# ### Display results

# %%
sns.boxplot(data=df)
sns.swarmplot(data=df)
# Out:
# <AxesSubplot:>
